# %% [markdown]
# <a href="https://colab.research.google.com/github/Trishank-yerramsetty/CSA0602-DAA/blob/main/TOPIC_1_LAB_DAA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Topic 1 programs

# %%
#1Q
arr = [10, 25, 30, 45, 50]
key = 30

for i in range(len(arr)):
    if arr[i] == key:
        print("Key found at index", i)
        break
else:
    print("Key not found")
# Out:
# Key found at index 2

# %%
#2Q
def binary_search(arr, key, low, high):
    if low > high:
        return -1

    mid = (low + high) // 2

    if arr[mid] == key:
        return mid
    elif key < arr[mid]:
        return binary_search(arr, key, low, mid - 1)
    else:
        return binary_search(arr, key, mid + 1, high)


arr = [5, 10, 15, 20, 25]
key = 20

result = binary_search(arr, key, 0, len(arr) - 1)

if result != -1:
    print("Key found at index", result)
else:
    print("Key not found")
# Out:
# Key found at index 3

# %%
#3Q
n = 5
fact = 1

for i in range(1, n + 1):
    fact = fact * i

print("Factorial =", fact)
# Out:
# Factorial = 120

# %%
#4Q
n = 6
a = 0
b = 1

for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c
# Out:
# 0 1 1 2 3 5

# %%
#5Q
A = [[1, 2],
     [3, 4]]

B = [[5, 6],
     [7, 8]]

C = [[0, 0],
     [0, 0]]

for i in range(2):
    for j in range(2):
        for k in range(2):
            C[i][j] += A[i][k] * B[k][j]

print(C)
# Out:
# [[19, 22], [43, 50]]

# %%
#6Q
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2

        left = arr[:mid]
        right = arr[mid:]

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1


arr = [38, 27, 43, 3, 9, 82, 10]

merge_sort(arr)

print(arr)
# Out:
# [3, 9, 10, 27, 38, 43, 82]

# %%
#7Q
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[-1]
    left = []
    right = []

    for i in arr[:-1]:
        if i < pivot:
            left.append(i)
        else:
            right.append(i)

    return quick_sort(left) + [pivot] + quick_sort(right)


arr = [10, 7, 8, 9, 1, 5]

print(quick_sort(arr))
# Out:
# [1, 5, 7, 8, 9, 10]

# %%
#8Q
def tower(n, A, B, C):
    if n > 0:
        tower(n-1, A, C, B)

        print("Move disk", n, "from", A, "to", C)

        tower(n-1, B, A, C)


n = 3
tower(n, "A", "B", "C")
# Out:
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C

# %%
#9Q
def gcd(a, b):
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

a = 48
b = 18

print("GCD =", gcd(a, b))
# Out:
# GCD = 6

# %%
#10Q
arr = [12, 11, 13, 5, 6]

for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j = j - 1

    arr[j + 1] = key

print(arr)
# Out:
# [5, 6, 11, 12, 13]

# %%
#11Q
def heapify(arr, n, i):
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)


arr = [4, 10, 3, 5, 1]
n = len(arr)

for i in range(n // 2 - 1, -1, -1):
    heapify(arr, n, i)

for i in range(n - 1, 0, -1):
    arr[0], arr[i] = arr[i], arr[0]
    heapify(arr, i, 0)

print(arr)
# Out:
# [1, 3, 4, 5, 10]

# %%
#12Q
def count_inversions(arr):
    count = 0

    for i in range(len(arr)):
        for j in range(i + 1, len(arr)):
            if arr[i] > arr[j]:
                count += 1

    return count


arr = [2, 4, 1, 3, 5]

print("Number of inversions =", count_inversions(arr))
# Out:
# Number of inversions = 3

# %%
#13Q
arr = [-2, -3, 4, -1, -2, 1, 5, -3]

max_sum = arr[0]
current_sum = arr[0]

for i in range(1, len(arr)):
    current_sum = max(arr[i], current_sum + arr[i])
    max_sum = max(max_sum, current_sum)

print("Maximum Subarray Sum =", max_sum)
# Out:
# Maximum Subarray Sum = 7

# %%
#14Q
x = 2
n = 10
result = 1

for i in range(n):
    result = result * x

print("Result =", result)
# Out:
# Result = 1024

# %%
#15Q
import math

points = [(1, 2), (4, 5), (7, 8), (3, 1)]

min_distance = float('inf')
pair = None

for i in range(len(points)):
    for j in range(i + 1, len(points)):
        x1, y1 = points[i]
        x2, y2 = points[j]

        distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)

        if distance < min_distance:
            min_distance = distance
            pair = (points[i], points[j])

print("Closest pair =", pair)
print("Distance =", min_distance)
# Out:
# Closest pair = ((1, 2), (3, 1))
# Distance = 2.23606797749979
